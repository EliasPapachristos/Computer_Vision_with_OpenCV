# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Open Image

# %%
img = cv2.imread('Images/car_plate.jpg')

# %% [markdown]
# ### Convert Image

# %%
def display(img):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111)
    new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(new_img)

# %%
display(img)

# %% [markdown]
# ### Create Classifier

# %%
plate_cascade = cv2.CascadeClassifier('Haarcascades/haarcascade_plate_number.xml')

# %% [markdown]
# ### It's a Kind of Magic

# %%
def detect_plate(img):
    
  
    plate_img = img.copy()
  
    plate_rects = plate_cascade.detectMultiScale(plate_img, scaleFactor=1.1, minNeighbors=1) 
    
    for (x,y,w,h) in plate_rects: 
        cv2.rectangle(plate_img, (x, y), (x + w, y + h), (255, 255, 255), 9) 
        
    return plate_img

# %% [markdown]
# ### Check the Results

# %%
result = detect_plate(img)

# %%
display(result)
